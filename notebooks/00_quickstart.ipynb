# %% [markdown]
# # 00_quickstart
# This notebook shows a **minimal** training/eval run using the package code.
# It uses a dummy dataset by default (replace with real loaders).

# %%
from sincpd.training.trainer import demo_training
demo_training()
